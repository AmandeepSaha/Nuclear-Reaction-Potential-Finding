# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import tplquad
from scipy.special import spherical_jn

# %% [markdown]
# ### the complete integral
#
# $$U_D(R) = \int^\infty _0 \int^\infty _0 \int^\infty _0 k^2 j_0(kR) v_D(k) F(\rho) g(E)   r_1^2 j_0(kr_1) \rho_p(r_1)  r_2^2 j_0(kr_2) \rho_t(r_2) dk dr_1 dr_2$$

# %%
def integrate(k, r2, r1,
              R,
              c1=11061.625,
              c2=2537.5,
              c=1.2521,
              mu1=4,
              mu2=2.5,
              gamma=1.7452,
              n=1):

    # Density functions
    def density_p(r):
        return 0.4229*np.exp(-0.7024 * r**2)

    def density_t(r, rho_0=0.207, a=0.425, R_0 = 2.1545):
        return rho_0/(1+np.exp((r-R_0)/a))
    
    # g(E)
    def g(E_lab, A=12):
        return (1-0.003*E_lab/A)

    # Total density
    rho = density_p(r1) + density_t(r2)

    # Fourier transform of M3Y interaction
    vD = (
        (4*np.pi*c1/mu1) / (mu1**2 + k**2)
        -
        (4*np.pi*c2/mu2) / (mu2**2 + k**2)
    )

    # Density-dependent factor
    F = c * (1 - gamma * rho**n)

    return 8*(
        k**2
        * spherical_jn(0, k*R)
        * vD
        * F
        * g(E_lab=141.7)
        * r1**2
        * r2**2
        * spherical_jn(0, k*r1)
        * spherical_jn(0, k*r2)
        * density_p(r1)
        * density_t(r2)
    )

# %%
R_vals = np.array([0.5*i for i in range(21)])

# %%
datas = []
errors = []

# %%
for i in range(0,21):

    result, error = tplquad(
        integrate,

        # r1: outer integral
        0, 5,

        # r2: middle integral
        lambda r1: 0,
        lambda r1: 8,

        # k: inner integral
        lambda r1, r2: 0,
        lambda r1, r2: 4,

        args=(R_vals[i],)
    )
    
    datas.append(result)
    errors.append(error)

# %%
len(datas)
# Out:
# 21

# %%
R = np.linspace(0,8,21)

# %%
datas
# Out:
# [74.93421350360026,
#  72.91958144321582,
#  67.12128851122867,
#  57.99338002784296,
#  45.88730623217096,
#  31.609097643980295,
#  17.367846751050376,
#  6.247891520156628,
#  0.04266974663623779,
#  -1.968655160719761,
#  -1.8359005225794751,
#  -1.155892391197743,
#  -0.587515446729469,
#  -0.26047049994918414,
#  -0.11033772620497355,
#  -0.04206094206706519,
#  -0.013409580310595992,
#  -0.006825217816991592,
#  -0.002532698644290192,
#  0.0008080967949375315,
#  -0.000896487185077513]

# %%
R_vals = np.array([0.5*i for i in range(21)])

plt.figure(figsize=(8, 5))

plt.plot(R_vals, datas, marker='o')

plt.xlabel('R (fm)')
plt.ylabel('U(R)')
plt.title('Variation of U(R) with R')


plt.grid(True)
plt.show()
